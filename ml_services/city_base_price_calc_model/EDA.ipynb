# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/final_dataset.csv')

corr = df.corr(numeric_only=True)

# %%
df.head()
# Out:
#    city_id city_name        date  city_tier  city_rank  median_income_weekly  \
# 0        0    Mumbai  2024-01-07          3          1           8884.823578
# 1        0    Mumbai  2024-01-14          3          1          10211.774685
# 2        0    Mumbai  2024-01-21          3          1          10397.506995
# 3        0    Mumbai  2024-01-28          3          1          11342.057243
# 4        0    Mumbai  2024-02-04          3          1           9442.560681
#
#    disruption_freq_weekly  avg_disruption_duration_hrs  \
# 0                       2                     1.648122
# 1                       1                     3.111240
# 2                       1                     1.206134
# 3                       2                     3.067711
# 4                       4                     1.125352
#
#    demand_stability_orders  total_orders_weekly  rainfall_mm  temperature_avg  \
# 0                 0.508781            76.331285    13.416286        25.328330
# ...

# %%
df.describe()
# Out:
#            city_id    city_tier    city_rank  median_income_weekly  \
# count  5200.000000  5200.000000  5200.000000           5200.000000
# mean     49.500000     2.010000    50.500000          12107.834311
# std      28.868846     0.793739    28.868846           3817.774146
# min       0.000000     1.000000     1.000000           3000.000000
# 25%      24.750000     1.000000    25.750000           9301.419953
# 50%      49.500000     2.000000    50.500000          11666.120692
# 75%      74.250000     3.000000    75.250000          14494.080507
# max      99.000000     3.000000   100.000000          23698.474076
#
#        disruption_freq_weekly  avg_disruption_duration_hrs  \
# count             5200.000000                  5200.000000
# mean                 3.275769                     2.290672
# std                  1.934618                     0.998444
# min                  0.000000                     0.512928
# 25%                  2.000000                     1.432586
# ...

# %%
df.shape
# Out:
# (5200, 15)

# %%
corr['weekly_insurance_premium'].sort_values(ascending=False)
# Out:
# weekly_insurance_premium       1.000000
# median_income_weekly           0.555568
# temperature_avg                0.479565
# city_rank                      0.397642
# city_id                        0.397642
# total_orders_weekly            0.394723
# disruption_freq_weekly         0.305803
# avg_disruption_duration_hrs    0.303807
# rainfall_mm                    0.295255
# holiday_flag                   0.167612
# event_flag                     0.143666
# city_tier                     -0.121687
# demand_stability_orders       -0.249591
# Name: weekly_insurance_premium, dtype: float64

# %%
plt.hist(df['weekly_insurance_premium'], bins=50)
plt.title("Premium Distribution")
plt.show()

# %%
df.hist(figsize=(15,10))
plt.show()

# %%
sns.scatterplot(
    x=df['income_to_risk_ratio'],
    y=df['weekly_insurance_premium']
)
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])

df.groupby('date')['weekly_insurance_premium'].mean().plot()
plt.title("Premium over time")
plt.show()
